# %% [markdown]
# # PGC - Demo Notebook: Data Visualization and Analysis Tools

# %%
import os
import sys
import pandas as pd

sys.path.append(os.path.abspath(".."))  # add path
from utils.interactive_dataframe import InteractiveDataFrame as iDataFrame

# %%
df = pd.read_csv("../datasets/CO2+Emissions/visualizing_global_co2_data.csv")
df = iDataFrame(pd.concat([df for _ in range(20)])[df.columns[:20]])
df.shape
# Out:
# (1011960, 20)

# %%
df.render_with_widgets()

# %%
# df.plt_topn("hist", 15)
# df.plt_topn("box", 15)
df.plt_topn("scatter", 15)

# %%
save_dict = {"hist": [0], "box": [1, 2, 3, 4], "scatter":[2,4]}
selector_plt = df.get_viz(save_dict)
iDataFrame.plt_from_selector(selector_plt)

# %%
# Saving viz in external file
df.save_plt(save_dict, fname="df_plot_selection.pickle")

# Loading from file or object
selector_plt = iDataFrame.load_plt("df_plot_selection.pickle")

# Ploting
iDataFrame.plt_from_selector(selector_plt)
